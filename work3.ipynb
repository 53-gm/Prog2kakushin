# %% [markdown]
# <a href="https://colab.research.google.com/github/53-gm/Prog2kakushin/blob/main/work3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# コッホ曲線の描画
#
# 再帰的に関数kochを呼び出すことで歪な線が書けた。
#
# 参考:https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%83%E3%83%9B%E6%9B%B2%E7%B7%9A

# %%
# turtle をColab環境で利用できるようにするため，Colabファイルを開いたときに一度だけ実行する
# !pip3 install ColabTurtlePlus

# 各プログラムの先頭に以下のimport文を書いてください．
from ColabTurtlePlus.Turtle import *
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ColabTurtlePlus
#   Downloading ColabTurtlePlus-2.0.1-py3-none-any.whl (31 kB)
# Installing collected packages: ColabTurtlePlus
# Successfully installed ColabTurtlePlus-2.0.1
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell

# %%
WINDOW_WIDTH = 300
WINDOW_HEIGHT = 900

def _setpos(t, pos): #線を描くやつの移動処理
  t.penup()
  t.setpos(pos)
  t.pendown()

def koch(t, len, n): #コッホ曲線を描く関数
  if n == 0:
    t.forward(len)
  else:
    koch(t, len / 3, n - 1)
    t.left(60) #左に60度回転
    koch(t, len / 3, n - 1)
    t.right(120) #右に120度回転
    koch(t, len / 3, n - 1)
    t.left(60) #左に60度回転
    koch(t, len / 3, n - 1)

clearscreen()   
setup(WINDOW_WIDTH,WINDOW_HEIGHT)

t = Turtle() #描画するものの作成
t.hideturtle() #線以外を非表示
t.speed(10) #描画スピード 0~10

for i in range(6):
  _setpos(t, (-WINDOW_WIDTH / 2, 400 - 100*i))
  koch(t, WINDOW_WIDTH, i)
# Out:
#       <svg width="300" height="900">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="0.0" y1="50.0" x2="300.0" y2="50.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="0.0" y1="150.0" x2="100.0" y2="150.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="150.0" x2="150.0" y2="63.397" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="150.0" y1="63.397" x2="200.0" y2="150.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="200.0" y1="150.0" x2="300.0" y2="150.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="0.0" y1="250.0" x2="33.333" y2="250.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="33.333" y1="250.0" x2="50.0" y2="221.132" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="50.0" y1="221.132" x2="66.667" y2="250.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="66.667" y1="250.0" x2="100.0" y2="250.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="250.0" x2="116.667" y2="221.132" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="116.667" y1="221.132" x2="100.0" y2="192.264" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="192.264" x2="133.333" y2="192.264" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="133.333" y1="192.264" x2="150.0" y2="163.396" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="150.0" y1="163.396" x2="166.667" y2="192.264" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="166.667" y1="192.264" x2="200.0" y2="192.264" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="200.0" y1="192.264" x2="183.333" y2="221.132" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="183.333" y1="221.132" x2="200.0" y2="250.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="200.0" y1="250.0" x2="233.333" y2="250.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="233.333" y1="250.0" x2="250.0" y2="221.132" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="250.0" y1="221.132" x2="266.667" y2="250.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="266.667" y1="250.0" x2="300.0" y2="250.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="0.0" y1="350.0" x2="11.111" y2="350.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="11.111" y1="350.0" x2="16.667" y2="340.377" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="16.667" y1="340.377" x2="22.223" y2="350.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="22.223" y1="350.0" x2="33.334" y2="350.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="33.334" y1="350.0" x2="38.89" y2="340.377" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="38.89" y1="340.377" x2="33.334" y2="330.754" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="33.334" y1="330.754" x2="44.445" y2="330.754" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="44.445" y1="330.754" x2="50.001" y2="321.131" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="50.001" y1="321.131" x2="55.557" y2="330.754" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="55.557" y1="330.754" x2="66.668" y2="330.754" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="66.668" y1="330.754" x2="61.112" y2="340.377" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="61.112" y1="340.377" x2="66.668" y2="350.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="66.668" y1="350.0" x2="77.779" y2="350.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="77.779" y1="350.0" x2="83.335" y2="340.377" stroke-linecap="round" style="stroke:black;stroke-width ...
